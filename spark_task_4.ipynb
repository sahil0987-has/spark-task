# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil0987-has/spark-task/blob/main/spark_task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task-4 : By The Sparks Foundation
#
# Name : Sudhansu Sekhar Choudhury
#
# Email ID : sudhansuchoudhury0039@gmail.com
#
# Github Profile :https://github.com/sahil0987-has
#
# Linkedin Profile :https://www.linkedin.com/in/sudhansu-choudhury-6a49261a4/
#
# Here I am importing the required library for model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !py -m pip install folium
# Out:
# /bin/bash: py: command not found

# %%
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# Reading the csv file

# %%
df = pd.read_csv("/content/drive/MyDrive/globalterrorismdb_0718dist.csv",encoding='latin1')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  1.970000e+11   1970       7     2  ...        0         0       0      NaN
# 1  1.970000e+11   1970       0     0  ...        1         1       1      NaN
# 2  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
# 3  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
# 4  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# Describing the dataframe

# %%
df.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325955e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991020e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009020e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014080e+11    2014.000000  ...       0.000000       0.000000
# max    2.017120e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# Collecting information about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# Noting down the total number of columns and their respective names

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# Finding out the correlation

# %%
df.corr()
# Out:
#             eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid    1.000000  0.999996  0.002705  ... -0.133252 -0.077851 -0.175606
# iyear      0.999996  1.000000  0.000139  ... -0.133253 -0.077847 -0.175596
# imonth     0.002705  0.000139  1.000000  ... -0.002034 -0.002554 -0.006336
# iday       0.018270  0.018254  0.005497  ... -0.001621 -0.002027 -0.001199
# extended   0.091762  0.091754 -0.000468  ...  0.075147  0.027335  0.080767
# ...             ...       ...       ...  ...       ...       ...       ...
# nreleased -0.181613 -0.181556 -0.011535  ...  0.040947  0.085055  0.064759
# INT_LOG   -0.143600 -0.143601 -0.002302  ...  0.996211  0.052537  0.891051
# INT_IDEO  -0.133252 -0.133253 -0.002034  ...  1.000000  0.082014  0.893811
# INT_MISC  -0.077851 -0.077847 -0.002554  ...  0.082014  1.000000  0.252193
# INT_ANY   -0.175606 -0.175596 -0.006336  ...  0.893811  0.252193  1.000000
#
# [77 rows x 77 columns]

# %% [markdown]
# Visualising the total daeth vs injuired in US

# %%
df.nkillus.plot(kind = 'line', color = 'red', label = ' Confirmed Fatalities for US', linewidth = 2, alpha = 0.7, grid = True, 
                 linestyle = ':', figsize = (15,15), fontsize=15)
df.nwoundus.plot(color = "black", label = ' Confirmed Non-Fatal Injuries for US', linewidth = 2, alpha = 0.7, grid = True, 
                 linestyle = '-.', figsize = (15,15), fontsize=15)

plt.legend(loc='upper right')    
plt.xlabel('Database Index', fontsize=10)              
plt.ylabel('Number of Dead or Injuries', fontsize=15)

plt.title('Dead vs Undead in US')             
plt.show()

# %%
sns.scatterplot(x = 'nkill', y = 'nwound',data=df,color="red")
plt.xlabel('Kill', fontsize=15)
plt.ylabel('Wound', fontsize=15)
plt.title('Kill - Wound Scatter Plot')
plt.show()

# %% [markdown]
# visualising total terrorist attacks in middle east and north america

# %%
middleEastData = df[df['region'] == 10]
middleEastData.iyear.plot(kind = 'hist', bins = 30, figsize = (15,15), color = 'red', fontsize=15)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.title('Terror attacks in middle east and north america')
plt.show()

# %%
df.nkillus.plot(kind = 'line', color = 'red', label = 'Death by Terrorism in the World', linewidth = 1.5, alpha = 0.7, grid = True, 
                 linestyle = ':', figsize = (15,15), fontsize=15)
middleEastData.nkillus.plot(color = "black", label = 'Death by Terrorism in the Middle East & North Africa', linewidth = 1.5, alpha = 0.7, 
                            grid = True, linestyle = '-.', figsize = (15,15), fontsize=15)

plt.legend(loc='upper right')      
plt.xlabel('Database Index', fontsize=15)               
plt.ylabel('Number of Dead', fontsize=15)

plt.title('Comparing death all over the world vs middle east and north america')             
plt.show()

# %% [markdown]
# Terrorist Attacks of a Particular year and their Locations

# %%
filter = df['iyear'] == 1970

# %%
df1= df[filter ]  
 
df2= df1.loc[:,'city':'longitude']  
df2 = df2.dropna()  
df2List = df2.values.tolist()

# %% [markdown]
# visualising terrror attack in the map

# %%
map = folium.Map(location = [0, 30], tiles='CartoDB positron', zoom_start=2)

markerCluster = folium.plugins.MarkerCluster().add_to(map)
for point in range(0, len(df2List)):
    folium.Marker(location=[df2List[point][1],df2List[point][2]], popup = df2List[point][0]).add_to(markerCluster)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# Total Number of people killed in terror attack

# %%
df3 = df.loc[:,'nkill']
print('Death in terror attack:', int(sum(df3.dropna())))
# Out:
# Death in terror attack: 411868

# %% [markdown]
# Different attacks that lead to death

# %%
df4 = df.loc[:,'attacktype1':'attacktype1_txt']
df5 = pd.concat([df4, df3], axis=1)

# %%
typeKill = df5.pivot_table(columns='attacktype1_txt', values='nkill', aggfunc='sum')
typeKill
# Out:
# attacktype1_txt  Armed Assault  Assassination  ...  Unarmed Assault  Unknown
# nkill                 160297.0        24920.0  ...            880.0  32381.0
#
# [1 rows x 9 columns]

# %%
typeKill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, nkill to nkill
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Armed Assault                        1 non-null      float64
#  1   Assassination                        1 non-null      float64
#  2   Bombing/Explosion                    1 non-null      float64
#  3   Facility/Infrastructure Attack       1 non-null      float64
#  4   Hijacking                            1 non-null      float64
#  5   Hostage Taking (Barricade Incident)  1 non-null      float64
#  6   Hostage Taking (Kidnapping)          1 non-null      float64
#  7   Unarmed Assault                      1 non-null      float64
#  8   Unknown                              1 non-null      float64
# dtypes: float64(9)
# memory usage: 80.0+ bytes

# %%
labels = typeKill.columns.tolist()  
transpoze = typeKill.T  
values = transpoze.values.tolist()
fig, ax = plt.subplots(figsize=(15,15), subplot_kw=dict(aspect="equal"))
plt.pie(values, startangle=90, autopct='%.2f%%')
plt.title('Types of terrorist attacks')
plt.legend(labels, loc='upper right', bbox_to_anchor = (1.3, 0.9), fontsize=15) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """

# %% [markdown]
# Armed assault and bombing/explosion are seen to be the cause of 77% of the deaths .
